# %% [markdown]
# # <u>Recommendation based on Popularity Ratings</u>

# %%
import pandas as pd

# %%
data = pd.read_csv("dataset/electronics_data_2.csv")

# %%
data.head(10)
# Out:
#        reviewerID        asin  \
# 0   AO94DHGC771SJ  0528881469
# 1   AMO214LNFCEI4  0528881469
# 2  A3N7T0DY83Y4IG  0528881469
# 3  A1H8PY3QHMQQA0  0528881469
# 4  A24EV6RXELQZ63  0528881469
# 5  A2JXAZZI9PHK9Z  0594451647
# 6  A2P5U7BDKKT7FW  0594451647
# 7   AAZ084UMH8VZ2  0594451647
# 8   AEZ3CR6BKIROJ  0594451647
# 9  A3BY5KCNQZXV5U  0594451647
#
#                                           reviewText  rating  \
# 0  We got this GPS for my husband who is an (OTR)...     5.0
# 1  I'm a professional OTR truck driver, and I bou...     1.0
# 2  Well, what can I say.  I've had this unit in m...     3.0
# 3  Not going to write a long review, even thought...     2.0
# 4  I've had mine for a year and here's what we go...     1.0
# 5  I am using this with a Nook HD+. It works as d...     5.0
# 6  The cable is very wobbly and sometimes disconn...     2.0
# 7  This adaptor is real easy to setup and use rig...     5.0
# 8  This adapter easily connects my Nook HD 7&#34;...     4.0
# 9  This product really works great but I found th...     5.0
#
#                                     summary  reviewTime  helpful_rev  \
# 0                           Gotta have GPS!  2013-06-02            0
# 1                         Very Disappointed  2010-11-25           12
# 2                            1st impression  2010-09-09           43
# 3                   Great grafics, POOR GPS  2010-11-24            9
# 4    Major issues, only excuses for support  2011-09-29            0
# 5                   HDMI Nook adapter cable  2014-01-03            3
# 6                    Cheap proprietary scam  2014-04-27            0
# 7               A Perfdect Nook HD+ hook up  2014-05-04            0
# 8             A nice easy to use accessory.  2014-07-11            0
# 9  This works great but read the details...  2014-01-20            3
#
#    not_helpful_rev rating_class  helpful_rev_ratio  rev_year  rev_month
# 0                0         good           0.000000      2013          6
# 1                3          bad           0.800000      2010         11
# 2                2          bad           0.955556      2010          9
# 3                1          bad           0.900000      2010         11
# 4                0          bad           0.000000      2011          9
# 5                0         good           1.000000      2014          1
# 6                0          bad           0.000000      2014          4
# 7                0         good           0.000000      2014          5
# 8                0         good           0.000000      2014          7
# 9                0         good           1.000000      2014          1

# %%
data.drop(["reviewText", "summary", "reviewTime", "helpful_rev",	"not_helpful_rev", "rating_class", "helpful_rev_ratio",	"rev_year",	"rev_month"], inplace = True, axis = 1)

# %%
data.head(5)
# Out:
#        reviewerID        asin  rating
# 0   AO94DHGC771SJ  0528881469     5.0
# 1   AMO214LNFCEI4  0528881469     1.0
# 2  A3N7T0DY83Y4IG  0528881469     3.0
# 3  A1H8PY3QHMQQA0  0528881469     2.0
# 4  A24EV6RXELQZ63  0528881469     1.0

# %% [markdown]
# ### <u>Calculating weighted average rating of each product</u>
# <b>weighted_avg = ( v / (v + m) ⋅ R ) + ( m / ( v + m ) ⋅ C )</b><br>
# <li>v is the number of votes for the movie</li>
# <li>m is the minimum votes required to be listed in the chart</li>
# <li>R is the average rating of the movie</li>
# <li>C is the mean rating across the whole report</li>

# %%
data2 = data.groupby(["asin","rating"]).count()
data2.reset_index(drop = False, inplace = True)

# %%
data2.head(2)
# Out:
#          asin  rating  reviewerID
# 0  0528881469     1.0           2
# 1  0528881469     2.0           1

# %%
data2["rating*pernumOfvote"] = data2["reviewerID"] * data2["rating"]
data2.head(2)
# Out:
#          asin  rating  reviewerID  rating*pernumOfvote
# 0  0528881469     1.0           2                  2.0
# 1  0528881469     2.0           1                  2.0

# %%
rating_pernumOfvote = pd.Series(data2.groupby("asin")["rating*pernumOfvote"].sum())
data3 = data.groupby(["asin"]).count()
totalNumVotesPerProduct = data3["rating"]
data3["avg_rating"] = rating_pernumOfvote / totalNumVotesPerProduct

# %%
R = data3["avg_rating"] 
v = data3["rating"]
m = data3["rating"].quantile(0.95)
C = data["rating"].mean()

def weighted_avg(v,R,C, m):
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
data3["weighted_avg"] = weighted_avg(v,R,C, m)
data3.sort_values(by = ["weighted_avg"], ascending=False, inplace = True)
data3.rename(columns = {"reviewerID" : "total_rating_given"}, inplace = True)
data3.drop(["rating", "avg_rating"] , axis = 1, inplace = True)
data3.reset_index(drop = False, inplace = True)

# %%
top_20 = data3.head(20)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
sns.set_theme(style = "whitegrid")
ax = sns.pointplot(x = "asin", y = "weighted_avg", data = top_20)
ax.set_xticklabels(ax.get_xticklabels() , rotation = 90)
plt.show()
